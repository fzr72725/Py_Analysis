# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('abalone.csv',names=['Sex','Length','Diameter','Height','Whole_Weight','Shucked_Weight','Viscera_Weight','Shell_Weight','Rings'])

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_Weight  Shucked_Weight  Viscera_Weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_Weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole_Weight  Shucked_Weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera_Weight  Shell_Weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
df_ring_group = df.groupby('Rings')

# %%
df_ring_mean = df_ring_group.mean()

# %%
df_ring_mean.plot(subplots=True,figsize=(12,20))
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x10f960d50>,
#        <matplotlib.axes.AxesSubplot object at 0x110430250>,
#        <matplotlib.axes.AxesSubplot object at 0x1104b4050>,
#        <matplotlib.axes.AxesSubplot object at 0x110508c50>,
#        <matplotlib.axes.AxesSubplot object at 0x11058aa50>,
#        <matplotlib.axes.AxesSubplot object at 0x1105ef590>,
#        <matplotlib.axes.AxesSubplot object at 0x11066f390>], dtype=object)
